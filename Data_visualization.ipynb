# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Inches  Ram  Weight        Price  Company_Apple  Company_Asus  \
# 0    13.3    8    1.37   71378.6832           True         False
# 1    13.3    8    1.34   47895.5232           True         False
# 2    15.6    8    1.86   30636.0000          False         False
# 3    15.4   16    1.83  135195.3360           True         False
# 4    13.3    8    1.37   96095.8080           True         False
#
#    Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# 0          False         False            False           False  ...
# 1          False         False            False           False  ...
# 2          False         False            False           False  ...
# 3          False         False            False           False  ...
# 4          False         False            False           False  ...
#
#    Gpu_Nvidia Quadro M620  Gpu_Nvidia Quadro M620M  OpSys_Chrome OS  \
# 0                   False                    False            False
# ...

# %%
#Final dataset check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Columns: 338 entries, Inches to OpSys_macOS
# dtypes: bool(334), float64(3), int64(1)
# memory usage: 465.3 KB

# %%
#Split Features & Target

# %%
X = df.drop("Price", axis=1)
y = df["Price"]

# %%
#Add Bias column

# %%
X = X.values
y = y.values

X = np.c_[np.ones(len(X)), X]

# %%
#EDA VISUALIZATION

# %%
#Basic distributions

# %%
plt.figure(figsize=(10,6))
df.hist()
plt.show()

# %%
#Price distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["Price"], kde=True)
plt.title("Price Distribution")
plt.show()

# %%
#Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
#RAM vs Price

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df["Ram"], y=df["Price"])
plt.title("RAM vs Price")
plt.show()

# %%
#Weight vs Price

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df["Weight"], y=df["Price"])
plt.title("Weight vs Price")
plt.show()

# %%
#Company vs Price

# %%
df_original = pd.read_csv("laptop_data.csv")

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="Company", y="Price", data=df_original)
plt.xticks(rotation=90)
plt.show()

# %%
#RAM countplot

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Ram", data=df_original)
plt.show()

# %%
#Pairplot

# %%
sns.pairplot(df_original[["Ram","Weight","Price"]])
plt.show()

# %%
#Company count

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Company", data=df_original)
plt.xticks(rotation=90)
plt.title("Number of Laptops by Company")
plt.show()

# %%
#Price by Company

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x="Company", y="Price", data=df_original)
plt.xticks(rotation=90)
plt.title("Price Distribution by Company")
plt.show()

# %%
#RAM vs Company

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x="Company", y="Ram", data=df_original)
plt.xticks(rotation=90)
plt.show()

# %%
#Weight distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(df_original["Weight"], kde=True)
plt.title("Weight Distribution")
plt.show()

# %%
#Price vs Weight

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="Weight", y="Price", hue="Ram", data=df_original)
plt.show()

# %%
#Company average price

# %%
avg_price = df_original.groupby("Company")["Price"].mean().sort_values()

plt.figure(figsize=(10,5))
avg_price.plot(kind="barh")
plt.title("Average Price by Company")
plt.show()

# %%
#Pairplot big

# %%
sns.pairplot(df_original[["Ram","Weight","Price"]])
plt.show()
